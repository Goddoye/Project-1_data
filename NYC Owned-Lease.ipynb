# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
file="C:/Users/oddoy/Documents/Jupyter Notebooks/ny-city-owned-and-leased-property/city-owned-and-leased-property-local-law-48-of-2011.csv"

# %%
owned_leased=pd.read_csv(file)
owned_leased.head()
# Out:
# C:\Users\oddoy\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3057: DtypeWarning: Columns (20,65) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#           Date Created  Borough  Map Atlas  Block  Lot             Address  \
# 0  2013-12-11T00:00:00        1        4.0      2    1     MARGINAL STREET
# 1  2013-12-11T00:00:00        1        4.0      2   23              PIER 6
# 2  2013-12-11T00:00:00        1        4.0      3    1        BATTERY PARK
# 3  2013-12-11T00:00:00        1        4.0      3    2  PETER MINUIT PLAZA
# 4  2013-12-11T00:00:00        1        4.0      3    3  PETER MINUIT PLAZA
#
#                      Parcel Name     Agency  \
# 0  BATTERY MARITIME BLDG / FERRY  DOT, DSBS
# 1                         PIER 6       DSBS
# 2                   BATTERY PARK      PARKS
# 3  PETER MINUIT PLAZA/BATTERY PK      PARKS
# ...
